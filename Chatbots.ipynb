# %% [markdown]
# #Part 1 (5 points).
#
#
# Eliza-like programs need to be able to handle person deixis: who is the speaker? Who is the addressee? Who is involved in the utterance? E.g.
#
# ”I am bored” —> “Why are you bored”?
#
# In English, such distinctions are generally indicated by pronouns (I, you, we, they, etc), and are marked on some verbs (I am vs. you are).
#
# Your Task: Develop a list of sentences that can be used to test a chatbot like Eliza to make sure it handles the person deixis correctly. This list must illustrate all the ways in which 1st and 2nd person are marked in English. This means that you must include all 1st and 2nd person pronouns, all 1st and 2nd person subject verb pairs with the verb be (maybe also considering tense differences — e.g. past vs. present).  You will be marked based on how complete your list is.
#
#
#
# You can type your sentences, expected responses, and a comment indicating what is being tested in any kind of file format (text, doc, tex, …), but please submit either a .pdf or a Jupyter notebook. Save the file as “YourSurname_Assignment3_Sentences”.

# %% [markdown]
# Am I real?
# *- Are you real?*
#
# We want food.
# *- You all want food?*
#
# What do you think of me?
# *- I don't think, do you?*
#
# Tell all of us something cool.
# *- Tell yourselves something cool.*
#
# You are mine.
# *- I am yours.*
#
#
# mine and ours (singular and plural possessive pronouns)
#
# myself and ourselves (singular and plural reflexive/intensive pronouns)
#
# you (singular and plural personal pronoun)
#
# yours (singular and plural possessive pronoun)
#
# yourself and yourselves (singular and plural reflexive/intensive pronouns)

# %% [markdown]
# #Part 2 (10 points).
#
#
# Implement an ELIZA-like program. You may choose a different domain than a Rogerian psychologist, if you wish, although keep in mind that you would need a domain in which your program can legitimately do a lot of simple repeating-back. You can look at Jurawski and Martin, Chapter 2, Section 2.1.6 for an example (pdf in Module 2).
#
#
#
# I have provided a Jupyter notebook with a skeleton script that handles input and output, and provides an example of the Python syntax for using regular expressions to modify strings.
#
# You can work on that one, just by modifying the reply() function, or you can implement everything from scratch in a different notebook.
#
# HINT: The basic approach is to read in a string of input from the user, modifying it successively using re.sub and regular expressions, (sometimes subtly, sometimes drastically, depending on the input string), and print out the final result. To maintain the illusion of AI, it is crucial that your ELIZA prints out grammatical strings. (You may assume that it is given grammatical input.)
#
#
#
# To get full marks, your program needs to satisfy (at least) the following specifications:
#
# Eliza should be able to handle person deixis, referring to itself in the first person and to the user in the second person.
#
#
# Hint: The basic strategy is to first replace any second person reference in the input with some string that's unlikely to show up otherwise. (The sample in the script does by replacing Eliza is, probably not the best choice). Then replace any first person reference in the input with second person reference. Finally, replace your otherwise unlikely string (from the first step) with first person reference (do you get why separating the task in steps is necessary?). Each of these steps will take several lines as you handle pronouns and verbs and upper and lower case letters (i.e., if the user types "My friend..." Eliza's output should be "Your friend..." and not "your friend...").
#
#
#
# Add at least two statements that find one keyword in the input and change the whole string to something different. E.G
# User: My partner is always bugging me about something or other.
#
# Eliza: Can you give me a specific example?
#
#
#
# Add at least two statements that find some keyword in the input, and return a significantly changed output that contains some part of the input that may vary from time to time. E.g.
#
#
# User: Well, my partner says I am sad much of the time.
#
# Eliza: I am sorry you are sad.
#
#
#
#
#
# Final notes of Part2. Feel free to add other use cases as you see fit. You need to test your program extensively making sure it returns grammatical sentences. Add a list of test sentences at the end of your Jupyter notebook.
#
#
#
# Submit the notebook via Canvas after renaming it “YourSurname_Assignment3_Eliza”.

# %%
# This cell is necessary to use reg expressions
#always run it first

# Style hint: Always import all the libraries that you need at the beginning of your code
# This is to make sure you don't forget any dependency
# And makes the dependencies needed by your code immediately visible to a second observer

import re

# %%
# This is the cell to modify for the assignment

def reply(string):
    '''
    This function modifies the user input passed as string
    based on a series of regular expressions.
    Returns the modified string as Eliza response.
    '''
    
    # Example
    # Replace all instances of "you are" with "Eliza is":
    # You don't want to keep this, as Eliza should not talk in 3rd person
    # This is here to show you how to use re.sub to switch pronouns
    
    string = re.sub(r'[Yy]ou are','I am',string)
    
    # Reminder: re.sub takes three arguments: 
    # a regular expression to search for in the string,
    # a replacement string to replace it with, and the string to
    # operate on.  It returns a new string, which the above expression
    # is storing in the variable 'string'.
    
    # ADD your reg expressions here
    string = re.sub(r'[Aa]m [Ii]','Are you', string)
    string = re.sub(r'[Ww]e', 'You all', string)
    string = re.sub(r'[Mm]e', 'You', string)
    string = re.sub(r'[Yy]ou', 'I', string)
    string = re.sub(r'[Uu]s', 'all of you', string)
    string = re.sub(r'\b[Ii]\b', 'You', string)
    string = re.sub(r'[Mm]y', 'Your', string)
    string = re.sub(r'[Mm]ine', 'Yours', string)
    string = re.sub(r'[Oo]urs', 'Yous', string)
    string = re.sub(r'[Oo]urselves', 'Yourselves', string)
    string = re.sub(r'[Mm]yself', 'Yourself', string)
    string = re.sub(r'[Yy]ours', 'Mine', string)


    # Return the reply
    # add "Eliza:"" in front of the reply to distinguish it from the user input
    return 'Elizalike: '+ string


def main():
    '''
    Main function.
    Requests the user input.
    Calls the reply function.
    Decides whether to keep chatting or to stop based on user input.
    '''
    
    print("Elizalike: Hello, I am Elizalike!  Talk to me! (Or type \"bye\" to quit.)\n")
    #set a flag to control the loop
    flag = True
    
    # Start a loop
    # Stops only when the user wants to
    while flag == True:

        # Read in the user's input
        string = input("Patient: ")

        # Allow user to quit
        if re.search(r'bye|Bye|BYE',string):

            print("Elizalike: Well, it was nice talking to you!\n")
            flag = False
        else:
            # if the user does not want to quit
            # reply
            print(reply(string))

# %%
# Run ALL previous cells before running this one
# Run this cell to start the program by calling main

main()
# Out:
# Elizalike: Hello, I am Elizalike!  Talk to me! (Or type "bye" to quit.)
#
# Patient: I love you
# Elizalike: You love You
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
# ...

# %% [markdown]
# #Part 3 (10 points).
#
#
# This is an evaluation task focused on comparing ELIZA and the neural network chatbot discussed in the video lecture (links for both are on Canvas). You must keep ELIZA, but can choose a different second chatbot if you want to (if you do, provide a link).
#
#
#
# This part includes 2 subtasks (5 points each).
#
#
#
# Task 1. Try and “break” each of the two chatbots (i.e. push them to answer in a way that would be unexpected for a human). You can take and submit screenshots of your conversations, but you also have to write about three paragraphs explaining your reasoning, your choice of sentences, and how the different bots handled them.
#
#
# Task 2. Now compare the behavior of the two bots in detail. You are left free to decide how to best to this. Generally, you should come up with sentences/questions to target the bots’ ability to handle the things you decided to test --- the specific choices are up to you but E.g. Ability to handle person deixis, other grammatical issues, ability to handle world knowledge, etc. You need to define your own evaluation metrics and test the bots over at least 3 distinct conversation aspects. Then, write a short discussion of your comparison including your test sets, an explanation of what you were evaluating, and how you evaluated the output (approximately one page not including the test examples). When testing Eliza, try to think how the bot responses can be related to the type of regular expressions we discussed in the previous lecture.
#
#
# Save the file as “YourSurname_Assignment3_Evaluation”.

# %% [markdown]
# ![ELIZABreak.JPG](data:image/jpeg;base64,...)
#
# Was able to get the ELIZA bot to offer a strange response by asking it personal questions that ELIZA admitted to "wanting to explore". After reinforcing the question however, ELIZA simply responsds with "We were talking about you, not me".

# %% [markdown]
# ![CleverbotWeird.JPG](data:image/jpeg;base64,...)
#
# Cleverbot did not take nearly as long to make it do something weird. I simply made an odd statement about the rain, to which Cleverbot responded "What God? Budha?".

# %% [markdown]
# It appears as though ELIZA tries to focus on circular engagement with the indiviual asking the questions. It focuses on making the questioner the primary target of any lengthy engagement, which is why ELIZA has a tough time providing any meaningful response.
#
# Cleverbot on the otherhand goes out of it's way to sound "smart" with witty comebacks to most questions. This can easily be broken by simply keeping the questioning mundane, forcing the bot to exaggerate more than necessary - sometimes randomly.

# %% [markdown]
# #Part 4 (5 points).
#
#
# In 3 to 5 paragraphs, discuss:
#
#
#
# Did you use any specific knowledge of English syntax/morphology in the two tasks you solved earlier?
# What about English makes implementing an English “speaking” ELIZA relatively straightforward? How complex do you think such a task would in some other language?
# What are the pros and cons of using regular expressions to model language? Think about what you learned about regular expressions, your work in the previous tasks, and the discussion of Eliza in this unit.
#
#
# Save the file as “YourSurname_Assignment3_Discussion”.

# %% [markdown]
# I suppose my inherint knowledge of the English language allowed me to more fluently understand how the chatbots weren't engaging properly. However, I'd make the case that the flaws of each bot could better be understood from their inherint design. Through understanding the scope of each project, it becomes obvious to see where they will fail.
#
# This is not to say that all chatbots would necessarily be this easy to rat out. Large players with massive resources would be able to assemble the software and linguistic teams necessary to design better code. This kind of code would definitely utliize far more elaborate regular expressions than the one's seen here.
#
# It'd be reasonable to assume this task could be performed with many other primary (not third world) languages, as there is enough technical and economic clout in many economies outside the United States to justify these systems.
